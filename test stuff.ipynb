# %%
import pandas as pd
import json
import urllib
import requests
from pandas.io.json import json_normalize
import re
# %matplotlib inline

# %%
imdb_df = pd.read_csv('./imdb_compiled.csv', index_col=0)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# Out:
#             tconst  ordering     nconst  category        job  \
# 6845982  tt8098424         7  nm5586630  producer   producer
# 6845983  tt8098424         8  nm5406722    editor         \N
# 6845984  tt8098424         9  nm6335994    editor         \N
# 6845985  tt8100326        10  nm9676791      self         \N
# 6845986  tt8100326         1  nm9676801      self         \N
# 6845987  tt8100326         2  nm9676821      self         \N
# 6845988  tt8100326         3  nm9676793      self         \N
# 6845989  tt8100326         4  nm9676796      self         \N
# 6845990  tt8100326         5  nm0596393    writer    creator
# 6845991  tt8100326         6  nm9676792      self         \N
# 6845992  tt8100326         7  nm9676815      self         \N
# 6845993  tt8100326         8  nm9676822      self         \N
# 6845994  tt8100326         9  nm9676805      self         \N
# 6845995  tt8101582         1  nm2518118  director         \N
# ...

# %%
response = requests.get('http://www.omdbapi.com/?i='+'tt3783958'+'&apikey=89e43da')
response.json()

json_res = response.json()
json_res
# Out:
# {'Actors': 'Ryan Gosling, Emma Stone, Amiée Conn, Terry Walters',
#  'Awards': 'Won 6 Oscars. Another 212 wins & 252 nominations.',
#  'BoxOffice': '$151,058,124',
#  'Country': 'USA, Hong Kong',
#  'DVD': '25 Apr 2017',
#  'Director': 'Damien Chazelle',
#  'Genre': 'Comedy, Drama, Music',
#  'Language': 'English',
#  'Metascore': '93',
#  'Plot': 'While navigating their careers in Los Angeles, a pianist and an actress fall in love while attempting to reconcile their aspirations for the future.',
#  'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BMzUzNDM2NzM2MV5BMl5BanBnXkFtZTgwNTM3NTg4OTE@._V1_SX300.jpg',
#  'Production': 'Liongate Films',
#  'Rated': 'PG-13',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.1/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#   {'Source': 'Metacritic', 'Value': '93/100'}],
#  'Released': '25 Dec 2016',
#  'Response': 'True',
#  'Runtime': '128 min',
#  'Title': 'La La Land',
#  'Type': 'movie',
# ...
